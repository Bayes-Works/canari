# %%
import copy
from pathlib import Path
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pytagi import Normalizer
import pytagi.metric as metric
from pytagi import Normalizer as normalizer
from canari import (
    DataProcess,
    Model,
    ModelOptimizer,
    SKF,
    SKFOptimizer,
    plot_data,
    plot_prediction,
    plot_skf_states,
    plot_states,
)
from canari.component import LocalTrend, LocalAcceleration, LstmNetwork, WhiteNoise

# %%
# data_file = "/Users/vuongdai/Desktop/backup_canari/TDSB_data/LGA/LGABAR/EXT/LGA010ESAPRG988.DAT"
data_file = "/Users/vuongdai/Desktop/backup_canari/TDSB_data/LTU/LTUBAR/PEN/ST/LTU014PIAEVA920.DAT"
df_raw = pd.read_csv(data_file,
                     sep=";",  # Semicolon as delimiter
                     quotechar='"',
                     engine="python",
                     na_values=[""],  # Treat empty strings as NaN
                     skipinitialspace=True,
                     encoding="ISO-8859-1",
                     )

# %%
df_raw.head()
# Out:
#         No pendule Amenagement Ouvrage              Date  Nombre Date  \
# 0  LTU014PIAEVA920         LTU  LTUBAR  2002-12-06 00:00      37596.0
# 1  LTU014PIAEVA920         LTU  LTUBAR  2002-12-07 00:00      37597.0
# 2  LTU014PIAEVA920         LTU  LTUBAR  2002-12-08 00:00      37598.0
# 3  LTU014PIAEVA920         LTU  LTUBAR  2002-12-09 00:00      37599.0
# 4  LTU014PIAEVA920         LTU  LTUBAR  2002-12-10 00:00      37600.0
#
#    Niveau Reservoir (m)  Deplacements cumulatif X (mm)  \
# 0                151.74                          -3.02
# 1                151.78                          -3.02
# 2                151.57                          -2.98
# 3                151.28                          -3.04
# 4                151.36                          -3.05
#
#    Deplacements cumulatif Y (mm)  Deplacements cumulatif Z (mm)  Remarque  \
# 0                          -0.70                           2.35       NaN
# 1                          -0.58                           2.33       NaN
# 2                          -0.63                           2.30       NaN
# 3                          -0.50                           2.26       NaN
# 4                          -0.41                           2.21       NaN
#
#    ...  Unnamed: 30  Unnamed: 31  Unnamed: 32  Unnamed: 33  Unnamed: 34  \
# 0  ...          NaN          NaN          NaN          NaN          NaN
# 1  ...          NaN          NaN          NaN          NaN          NaN
# 2  ...          NaN          NaN          NaN          NaN          NaN
# 3  ...          NaN          NaN          NaN          NaN          NaN
# 4  ...          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 35  Unnamed: 36  Unnamed: 37  Unnamed: 38  Unnamed: 39
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
# [5 rows x 40 columns]

# %%
# df = df_raw[["Ext/Contraction (mm)"]]
df = df_raw[["Deplacements cumulatif X (mm)"]]

df.columns = ["ext"]
df.index = pd.to_datetime(df_raw["Date"])
# Resampling to weekly
df = df.resample("W").last()

# %%
import matplotlib.dates as mdates
fig, ax = plt.subplots(figsize=(10, 4))
plt.plot(df.index, df["ext"], color="red")
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y"))
plt.xticks(rotation=45)
plt.show()

# %%
# Data pre-processing
output_col = [0]
scale_const_mean = np.nanmean(df["ext"].iloc[0:52*2])
scale_const_std = np.nanstd(df["ext"].iloc[0:52*2])
data_processor = DataProcess(
    data=df,
    time_covariates=["week_of_year"],
    train_split=0.2,
    validation_split=0.08,
    test_split=0.67,
    output_col=output_col,
    scale_const_mean=[scale_const_mean, 26.95754717],
    scale_const_std=[scale_const_std, 15.22916423],
)
train_data, validation_data, test_data, all_data = data_processor.get_splits()
seed = np.random.randint(0, 100)

# %%
fig, ax = plt.subplots(figsize=(10, 6))
plot_data(
    data_processor=data_processor,
    plot_column=output_col,
    standardization=True,
    plot_test_data=False,
    sub_plot=ax,
    validation_label="y",
)

# %%
param_optimization = True
smoother = True
num_trial_optim_model = 100

# %%
######### Define model with parameters #########
def model_with_parameters(param, train_data, validation_data):
    model = Model(
        LocalTrend(),
        LstmNetwork(
            look_back_len=param["look_back_len"],
            num_features=2,
            num_layer=1,
            infer_len=52 * 3,
            num_hidden_unit=50,
            manual_seed=seed,
            smoother=smoother,
        ),
        WhiteNoise(std_error=param["sigma_v"]),
    )

    model.auto_initialize_baseline_states(train_data["y"][0 : 52 * 3])
    num_epoch = 50
    for epoch in range(num_epoch):
        mu_validation_preds, std_validation_preds, _ = model.lstm_train(
            train_data=train_data,
            validation_data=validation_data,
        )

        mu_validation_preds_unnorm = normalizer.unstandardize(
            mu_validation_preds,
            data_processor.scale_const_mean[data_processor.output_col],
            data_processor.scale_const_std[data_processor.output_col],
        )

        std_validation_preds_unnorm = normalizer.unstandardize_std(
            std_validation_preds,
            data_processor.scale_const_std[data_processor.output_col],
        )

        validation_obs = data_processor.get_data("validation").flatten()
        validation_log_lik = metric.log_likelihood(
            prediction=mu_validation_preds_unnorm,
            observation=validation_obs,
            std=std_validation_preds_unnorm,
        )

        model.early_stopping(
            evaluate_metric=-validation_log_lik,
            current_epoch=epoch,
            max_epoch=num_epoch,
        )
        model.metric_optim = model.early_stop_metric

        if model.stop_training:
            break

    #### Define SKF model with parameters #########

    abnorm_model = Model(
        LocalAcceleration(),
        LstmNetwork(),
        WhiteNoise(),
    )
    skf = SKF(
        norm_model=model,
        abnorm_model=abnorm_model,
        std_transition_error=param["std_transition_error"],
        norm_to_abnorm_prob=param["norm_to_abnorm_prob"],
    )

    skf.save_initial_states()

    filter_marginal_abnorm_prob, states, mu_preds, std_preds = skf.filter(
        data=all_data
    )

    mu_preds_unnorm = normalizer.unstandardize(
        mu_preds,
        data_processor.scale_const_mean[data_processor.output_col],
        data_processor.scale_const_std[data_processor.output_col],
    )

    std_preds_unnorm = normalizer.unstandardize_std(
        std_preds,
        data_processor.scale_const_std[data_processor.output_col],
    )

    obs_all = data_processor.get_data("all").flatten()
    log_lik_all = metric.log_likelihood(
        prediction=mu_preds_unnorm,
        observation=obs_all,
        std=std_preds_unnorm,
    )
    skf.metric_optim = -log_lik_all

    skf.load_initial_states()

    return skf, filter_marginal_abnorm_prob, states

# %%
if param_optimization:
    param_space = {
        "look_back_len": [12, 52],
        "sigma_v": [1e-3, 2e-1],
        "std_transition_error": [1e-6, 1e-4],
        "norm_to_abnorm_prob": [1e-6, 1e-4],
    }
    # Define optimizer
    model_optimizer = ModelOptimizer(
        model=model_with_parameters,
        param_space=param_space,
        train_data=train_data,
        validation_data=validation_data,
        num_optimization_trial=num_trial_optim_model,
    )
    model_optimizer.optimize()
    # Get best model
    param = model_optimizer.get_best_param()
    skf_optim, filter_marginal_abnorm_prob, states = model_with_parameters(
        param, train_data, validation_data
    )

    skf_optim_dict = skf_optim.get_dict()
    skf_optim_dict["model_param"] = param
    skf_optim_dict["cov_names"] = train_data["cov_names"]
    with open("/Users/vuongdai/GitHub/canari/saved_params/benchmark_14_LL_1.pkl", "wb") as f:
        pickle.dump(skf_optim_dict, f)
else:
    with open("/Users/vuongdai/GitHub/canari/saved_params/benchmark_14_LL_1.pkl", "rb") as f:
        skf_optim_dict = pickle.load(f)
    skf_optim = SKF.load_dict(skf_optim_dict)

filter_marginal_abnorm_prob, states, *_ = skf_optim.filter(data=all_data)
smooth_marginal_abnorm_prob, states = skf_optim.smoother()

fig, ax = plot_skf_states(
    data_processor=data_processor,
    states=states,
    model_prob=filter_marginal_abnorm_prob,
)
fig.suptitle("SKF hidden states", fontsize=10, y=1)
plt.savefig("/Users/vuongdai/GitHub/canari/saved_results/BM14_1.png")
plt.show()
# Out:
# #   1/100 - Metric: 0.354 - Parameter: {'look_back_len': 47, 'sigma_v': 0.14867382491316355, 'std_transition_error': 9.534705467017994e-05, 'norm_to_abnorm_prob': 2.444919791554305e-05}
# #   2/100 - Metric: 1.197 - Parameter: {'look_back_len': 24, 'sigma_v': 0.06459850848182422, 'std_transition_error': 6.095888464631934e-05, 'norm_to_abnorm_prob': 7.750699698320784e-05}
# #   3/100 - Metric: 6.137 - Parameter: {'look_back_len': 23, 'sigma_v': 0.06400998043733805, 'std_transition_error': 3.1164952879051886e-06, 'norm_to_abnorm_prob': 1.1145414623629483e-05}
# #   4/100 - Metric: 0.620 - Parameter: {'look_back_len': 12, 'sigma_v': 0.1076448854750399, 'std_transition_error': 4.803905617660847e-05, 'norm_to_abnorm_prob': 7.061750524706087e-05}
# #   5/100 - Metric: 0.733 - Parameter: {'look_back_len': 30, 'sigma_v': 0.19360844410838296, 'std_transition_error': 2.933872896887777e-05, 'norm_to_abnorm_prob': 9.516151686378584e-05}
# #   6/100 - Metric: 2.717 - Parameter: {'look_back_len': 12, 'sigma_v': 0.022031876181674504, 'std_transition_error': 1.9867192972504957e-05, 'norm_to_abnorm_prob': 6.4557948476693e-06}
# #   7/100 - Metric: 0.721 - Parameter: {'look_back_len': 45, 'sigma_v': 0.05591220139064933, 'std_transition_error': 4.634974671184628e-05, 'norm_to_abnorm_prob': 7.335269908106505e-05}
# #   8/100 - Metric: 0.515 - Parameter: {'look_back_len': 40, 'sigma_v': 0.160064523297204, 'std_transition_error': 7.853144877956596e-05, 'norm_to_abnorm_prob': 1.153508627598452e-06}
# #   9/100 - Metric: 0.442 - Parameter: {'look_back_len': 15, 'sigma_v': 0.15774422801579527, 'std_transition_error': 9.954942826448975e-05, 'norm_to_abnorm_prob': 6.875380977959612e-05}
# #  10/100 - Metric: 1.154 - Parameter: {'look_back_len': 19, 'sigma_v': 0.06843192346888612, 'std_transition_error': 1.2154499570545251e-05, 'norm_to_abnorm_prob': 7.189331079261622e-05}
# #  11/100 - Metric: 0.543 - Parameter: {'look_back_len': 41, 'sigma_v': 0.058595680348297714, 'std_transition_error': 6.401773211225578e-05, 'norm_to_abnorm_prob': 5.298608220850508e-05}
# #  12/100 - Metric: 1.402 - Parameter: {'look_back_len': 34, 'sigma_v': 0.0249118007679336, 'std_transition_error': 8.014089616391496e-05, 'norm_to_abnorm_prob': 7.45622605828979e-05}
# #  13/100 - Metric: 1.692 - Parameter: {'look_back_len': 31, 'sigma_v': 0.16497386324158353, 'std_transition_error': 9.015598480583131e-06, 'norm_to_abnorm_prob': 2.4996410460110463e-05}
# #  14/100 - Metric: 0.847 - Parameter: {'look_back_len': 43, 'sigma_v': 0.10159855446411663, 'std_transition_error': 4.9368040050247656e-05, 'norm_to_abnorm_prob': 7.482000198501348e-05}
# #  15/100 - Metric: 0.370 - Parameter: {'look_back_len': 31, 'sigma_v': 0.1241467063176672, 'std_transition_error': 6.203719983572281e-05, 'norm_to_abnorm_prob': 7.964711100576725e-05}
# #  16/100 - Metric: 0.448 - Parameter: {'look_back_len': 16, 'sigma_v': 0.09448018997779643, 'std_transition_error': 8.59554933708839e-05, 'norm_to_abnorm_prob': 4.509257250957673e-05}
# #  17/100 - Metric: 0.521 - Parameter: {'look_back_len': 31, 'sigma_v': 0.08670590798970762, 'std_transition_error': 9.490962576826659e-05, 'norm_to_abnorm_prob': 9.6625656038819e-05}
# #  18/100 - Metric: 0.625 - Parameter: {'look_back_len': 41, 'sigma_v': 0.12602987126572524, 'std_transition_error': 3.5163313113499804e-05, 'norm_to_abnorm_prob': 6.088996092390685e-05}
# #  19/100 - Metric: 0.773 - Parameter: {'look_back_len': 46, 'sigma_v': 0.015381276353454085, 'std_transition_error': 6.299752981174156e-05, 'norm_to_abnorm_prob': 9.459487123482067e-05}
# #  20/100 - Metric: 0.591 - Parameter: {'look_back_len': 33, 'sigma_v': 0.1089660834488607, 'std_transition_error': 8.00761011086029e-05, 'norm_to_abnorm_prob': 7.211071033709547e-05}
# #  21/100 - Metric: 1.147 - Parameter: {'look_back_len': 48, 'sigma_v': 0.010503460830895553, 'std_transition_error': 9.108040153299433e-05, 'norm_to_abnorm_prob': 9.700676023147484e-05}
# #  22/100 - Metric: 1.190 - Parameter: {'look_back_len': 22, 'sigma_v': 0.14078550254331304, 'std_transition_error': 1.3848071664637868e-05, 'norm_to_abnorm_prob': 9.150457311262765e-05}
# #  23/100 - Metric: 1.538 - Parameter: {'look_back_len': 30, 'sigma_v': 0.07231864032981936, 'std_transition_error': 1.3014980680776384e-05, 'norm_to_abnorm_prob': 7.839816918658083e-05}
# #  24/100 - Metric: 0.750 - Parameter: {'look_back_len': 39, 'sigma_v': 0.05876944480852926, 'std_transition_error': 7.658999650021874e-05, 'norm_to_abnorm_prob': 1.0156776191410466e-05}
# #  25/100 - Metric: 4.798 - Parameter: {'look_back_len': 27, 'sigma_v': 0.1900163606383582, 'std_transition_error': 3.0286626403299654e-06, 'norm_to_abnorm_prob': 5.680496889596777e-05}
# #  26/100 - Metric: 0.790 - Parameter: {'look_back_len': 17, 'sigma_v': 0.14567440652814154, 'std_transition_error': 3.8432225277751986e-05, 'norm_to_abnorm_prob': 8.548579428718257e-05}
# #  27/100 - Metric: 0.591 - Parameter: {'look_back_len': 27, 'sigma_v': 0.18633604085618258, 'std_transition_error': 6.32281350218878e-05, 'norm_to_abnorm_prob': 7.883801072981304e-05}
# #  28/100 - Metric: 0.472 - Parameter: {'look_back_len': 34, 'sigma_v': 0.12345660381670596, 'std_transition_error': 6.453035199086653e-05, 'norm_to_abnorm_prob': 3.680166262913155e-05}
# #  29/100 - Metric: 0.612 - Parameter: {'look_back_len': 26, 'sigma_v': 0.09636007700277768, 'std_transition_error': 7.171479389112128e-05, 'norm_to_abnorm_prob': 3.5696018560895515e-05}
# #  30/100 - Metric: 0.371 - Parameter: {'look_back_len': 13, 'sigma_v': 0.04804105055329261, 'std_transition_error': 8.381869330448925e-05, 'norm_to_abnorm_prob': 5.632845898224435e-05}
# #  31/100 - Metric: 0.644 - Parameter: {'look_back_len': 48, 'sigma_v': 0.14125299469346764, 'std_transition_error': 4.7660884429548676e-05, 'norm_to_abnorm_prob': 2.490394636049722e-05}
# #  32/100 - Metric: 2.158 - Parameter: {'look_back_len': 12, 'sigma_v': 0.002779604211554536, 'std_transition_error': 7.259194077669146e-05, 'norm_to_abnorm_prob': 3.8144219745989586e-05}
# #  33/100 - Metric: 0.415 - Parameter: {'look_back_len': 16, 'sigma_v': 0.14846526733172385, 'std_transition_error': 9.870203512792564e-05, 'norm_to_abnorm_prob': 9.189702263354485e-05}
# #  34/100 - Metric: 0.314 - Parameter: {'look_back_len': 47, 'sigma_v': 0.1612225186435866, 'std_transition_error': 9.668114781001326e-05, 'norm_to_abnorm_prob': 3.42867353670984e-05}
# #  35/100 - Metric: 0.482 - Parameter: {'look_back_len': 48, 'sigma_v': 0.14691440952373555, 'std_transition_error': 9.905726740226676e-05, 'norm_to_abnorm_prob': 1.0088893410969412e-05}
# #  36/100 - Metric: 0.373 - Parameter: {'look_back_len': 51, 'sigma_v': 0.1613218941916508, 'std_transition_error': 9.816872923913651e-05, 'norm_to_abnorm_prob': 3.6455330612609415e-05}
# #  37/100 - Metric: 0.399 - Parameter: {'look_back_len': 45, 'sigma_v': 0.13400620129619684, 'std_transition_error': 8.948688494659554e-05, 'norm_to_abnorm_prob': 5.874768679430837e-05}
# #  38/100 - Metric: 0.470 - Parameter: {'look_back_len': 18, 'sigma_v': 0.03197404021216637, 'std_transition_error': 7.77038103374234e-05, 'norm_to_abnorm_prob': 7.347060493662556e-05}
# #  39/100 - Metric: 0.432 - Parameter: {'look_back_len': 19, 'sigma_v': 0.03934403500881329, 'std_transition_error': 5.3633063058478435e-05, 'norm_to_abnorm_prob': 6.268451133940765e-05}
# #  40/100 - Metric: 0.388 - Parameter: {'look_back_len': 39, 'sigma_v': 0.19851493870935433, 'std_transition_error': 7.593918090488274e-05, 'norm_to_abnorm_prob': 3.832430777404423e-05}
# #  41/100 - Metric: 0.444 - Parameter: {'look_back_len': 38, 'sigma_v': 0.18406667880066724, 'std_transition_error': 9.323769673760823e-05, 'norm_to_abnorm_prob': 2.4273149426236944e-05}
# #  42/100 - Metric: 0.677 - Parameter: {'look_back_len': 48, 'sigma_v': 0.09169612911262787, 'std_transition_error': 9.922444359555524e-05, 'norm_to_abnorm_prob': 4.048432594583047e-05}
# #  43/100 - Metric: 0.524 - Parameter: {'look_back_len': 46, 'sigma_v': 0.17229611746572135, 'std_transition_error': 9.99980083529395e-05, 'norm_to_abnorm_prob': 3.693160124232484e-05}
# #  44/100 - Metric: 0.544 - Parameter: {'look_back_len': 50, 'sigma_v': 0.15918900828722085, 'std_transition_error': 8.686644322231591e-05, 'norm_to_abnorm_prob': 3.661403145049779e-05}
# #  45/100 - Metric: 0.448 - Parameter: {'look_back_len': 51, 'sigma_v': 0.1721544993086214, 'std_transition_error': 7.277057913627727e-05, 'norm_to_abnorm_prob': 2.2309158063954872e-05}
# #  46/100 - Metric: 0.344 - Parameter: {'look_back_len': 13, 'sigma_v': 0.05706798404585834, 'std_transition_error': 9.97219830196982e-05, 'norm_to_abnorm_prob': 4.2811399010851026e-05}
# #  47/100 - Metric: 0.741 - Parameter: {'look_back_len': 27, 'sigma_v': 0.108855434850591, 'std_transition_error': 4.95910341378321e-05, 'norm_to_abnorm_prob': 7.850277152006527e-05}
# #  48/100 - Metric: 0.898 - Parameter: {'look_back_len': 18, 'sigma_v': 0.036549877318075935, 'std_transition_error': 9.597787745709501e-05, 'norm_to_abnorm_prob': 5.2538387468018524e-05}
# #  49/100 - Metric: 0.719 - Parameter: {'look_back_len': 12, 'sigma_v': 0.07267173085797934, 'std_transition_error': 9.366416863993074e-05, 'norm_to_abnorm_prob': 3.3700392774077266e-05}
# #  50/100 - Metric: 0.332 - Parameter: {'look_back_len': 14, 'sigma_v': 0.07937033260652154, 'std_transition_error': 7.698497550034751e-05, 'norm_to_abnorm_prob': 4.083469672794679e-05}
# #  51/100 - Metric: 1.322 - Parameter: {'look_back_len': 12, 'sigma_v': 0.03537000267841757, 'std_transition_error': 9.855029129642482e-05, 'norm_to_abnorm_prob': 7.722994404278886e-05}
# #  52/100 - Metric: 0.871 - Parameter: {'look_back_len': 18, 'sigma_v': 0.07455321721890362, 'std_transition_error': 4.18668815854178e-05, 'norm_to_abnorm_prob': 3.228653598985927e-05}
# #  53/100 - Metric: 0.404 - Parameter: {'look_back_len': 36, 'sigma_v': 0.1412935142752742, 'std_transition_error': 6.56216093013833e-05, 'norm_to_abnorm_prob': 9.05978107135332e-05}
# #  54/100 - Metric: 0.610 - Parameter: {'look_back_len': 16, 'sigma_v': 0.07551521307973388, 'std_transition_error': 7.50811669784835e-05, 'norm_to_abnorm_prob': 5.155801709057858e-05}
# #  55/100 - Metric: 0.488 - Parameter: {'look_back_len': 15, 'sigma_v': 0.05286681520658924, 'std_transition_error': 7.42031597969234e-05, 'norm_to_abnorm_prob': 4.192490263288968e-05}
# #  56/100 - Metric: 0.976 - Parameter: {'look_back_len': 12, 'sigma_v': 0.06074628548798761, 'std_transition_error': 8.329249039033491e-05, 'norm_to_abnorm_prob': 5.583736790136663e-05}
# #  57/100 - Metric: 0.558 - Parameter: {'look_back_len': 22, 'sigma_v': 0.08488376252844333, 'std_transition_error': 9.35540898345052e-05, 'norm_to_abnorm_prob': 6.777727168890232e-05}
# #  58/100 - Metric: 0.439 - Parameter: {'look_back_len': 16, 'sigma_v': 0.17777610294129792, 'std_transition_error': 7.432732104753896e-05, 'norm_to_abnorm_prob': 2.193513785781346e-06}
# #  59/100 - Metric: 0.454 - Parameter: {'look_back_len': 18, 'sigma_v': 0.043707715610212694, 'std_transition_error': 9.920605660563741e-05, 'norm_to_abnorm_prob': 4.543195982276085e-05}
# #  60/100 - Metric: 2.973 - Parameter: {'look_back_len': 44, 'sigma_v': 0.09035558533349346, 'std_transition_error': 9.37328016776678e-06, 'norm_to_abnorm_prob': 3.34958235334463e-05}
# #  61/100 - Metric: 0.388 - Parameter: {'look_back_len': 13, 'sigma_v': 0.03407564479457584, 'std_transition_error': 9.760619371623675e-05, 'norm_to_abnorm_prob': 4.6996586125674344e-06}
# #  62/100 - Metric: 0.448 - Parameter: {'look_back_len': 15, 'sigma_v': 0.11004334913283563, 'std_transition_error': 7.454960573099987e-05, 'norm_to_abnorm_prob': 3.754352520424045e-05}
# #  63/100 - Metric: 1.601 - Parameter: {'look_back_len': 45, 'sigma_v': 0.12220515561307665, 'std_transition_error': 9.19816785398465e-05, 'norm_to_abnorm_prob': 2.660499998818296e-05}
# #  64/100 - Metric: 0.709 - Parameter: {'look_back_len': 43, 'sigma_v': 0.1332199272663957, 'std_transition_error': 9.641290714187256e-05, 'norm_to_abnorm_prob': 2.339691262012974e-05}
# #  65/100 - Metric: 0.332 - Parameter: {'look_back_len': 37, 'sigma_v': 0.1391740713031607, 'std_transition_error': 8.825643144519488e-05, 'norm_to_abnorm_prob': 4.226381696778279e-05}
# #  66/100 - Metric: 0.913 - Parameter: {'look_back_len': 35, 'sigma_v': 0.009170881924893029, 'std_transition_error': 5.0167441854714807e-05, 'norm_to_abnorm_prob': 3.464905697380504e-05}
# #  67/100 - Metric: 0.529 - Parameter: {'look_back_len': 33, 'sigma_v': 0.11933536208451385, 'std_transition_error': 9.187751226885612e-05, 'norm_to_abnorm_prob': 3.035803050933809e-05}
# #  68/100 - Metric: 3.753 - Parameter: {'look_back_len': 46, 'sigma_v': 0.16700203681620077, 'std_transition_error': 3.3939887115177746e-06, 'norm_to_abnorm_prob': 7.349157249921384e-05}
# #  69/100 - Metric: 0.451 - Parameter: {'look_back_len': 34, 'sigma_v': 0.12424736252467058, 'std_transition_error': 6.895930730868496e-05, 'norm_to_abnorm_prob': 5.650309236407018e-05}
# #  70/100 - Metric: 0.688 - Parameter: {'look_back_len': 20, 'sigma_v': 0.0720117458725352, 'std_transition_error': 6.608538591089969e-05, 'norm_to_abnorm_prob': 1.0636593300723002e-05}
# #  71/100 - Metric: 0.415 - Parameter: {'look_back_len': 31, 'sigma_v': 0.1859958520287666, 'std_transition_error': 9.286622548084194e-05, 'norm_to_abnorm_prob': 5.1972619961834985e-05}
# #  72/100 - Metric: 0.362 - Parameter: {'look_back_len': 36, 'sigma_v': 0.15991502909583144, 'std_transition_error': 9.997170639656851e-05, 'norm_to_abnorm_prob': 4.71006248081133e-05}
# #  73/100 - Metric: 0.338 - Parameter: {'look_back_len': 39, 'sigma_v': 0.12619995150172097, 'std_transition_error': 8.70847940780211e-05, 'norm_to_abnorm_prob': 4.231139861989638e-05}
# #  74/100 - Metric: 0.494 - Parameter: {'look_back_len': 33, 'sigma_v': 0.16485071813546257, 'std_transition_error': 8.804773571640687e-05, 'norm_to_abnorm_prob': 4.6743832653763555e-05}
# #  75/100 - Metric: 0.440 - Parameter: {'look_back_len': 34, 'sigma_v': 0.13380388364727291, 'std_transition_error': 9.007399186649995e-05, 'norm_to_abnorm_prob': 6.886683158776394e-05}
# #  76/100 - Metric: 0.322 - Parameter: {'look_back_len': 40, 'sigma_v': 0.1388223968320309, 'std_transition_error': 8.968303692867479e-05, 'norm_to_abnorm_prob': 5.940942735455257e-05}
# #  77/100 - Metric: 0.345 - Parameter: {'look_back_len': 38, 'sigma_v': 0.12713893671729676, 'std_transition_error': 8.44635639625184e-05, 'norm_to_abnorm_prob': 4.7584033070227435e-05}
# #  78/100 - Metric: 0.437 - Parameter: {'look_back_len': 42, 'sigma_v': 0.10044137546388443, 'std_transition_error': 8.584982235999608e-05, 'norm_to_abnorm_prob': 5.165747147828573e-05}
# #  79/100 - Metric: 0.443 - Parameter: {'look_back_len': 39, 'sigma_v': 0.09421138038790894, 'std_transition_error': 8.182411877686198e-05, 'norm_to_abnorm_prob': 4.3897607234750706e-05}
# #  80/100 - Metric: 0.456 - Parameter: {'look_back_len': 34, 'sigma_v': 0.10837285841029352, 'std_transition_error': 8.720557869955899e-05, 'norm_to_abnorm_prob': 4.554751901529999e-05}
# #  81/100 - Metric: 0.380 - Parameter: {'look_back_len': 39, 'sigma_v': 0.15668233150112693, 'std_transition_error': 7.330800781555176e-05, 'norm_to_abnorm_prob': 3.154826639109495e-05}
# #  82/100 - Metric: 0.586 - Parameter: {'look_back_len': 43, 'sigma_v': 0.1648389999328103, 'std_transition_error': 7.511911232576514e-05, 'norm_to_abnorm_prob': 6.503548222507057e-05}
# #  83/100 - Metric: 0.338 - Parameter: {'look_back_len': 37, 'sigma_v': 0.14497757581089576, 'std_transition_error': 8.548341948309906e-05, 'norm_to_abnorm_prob': 4.564047543336411e-05}
# #  84/100 - Metric: 0.323 - Parameter: {'look_back_len': 39, 'sigma_v': 0.13726872232201975, 'std_transition_error': 9.401193361910235e-05, 'norm_to_abnorm_prob': 5.0116833344851424e-05}
# #  85/100 - Metric: 0.387 - Parameter: {'look_back_len': 39, 'sigma_v': 0.15135818111643398, 'std_transition_error': 8.306309898845498e-05, 'norm_to_abnorm_prob': 3.904531520727386e-05}
# #  86/100 - Metric: 0.336 - Parameter: {'look_back_len': 38, 'sigma_v': 0.13629292562018586, 'std_transition_error': 8.16870199617691e-05, 'norm_to_abnorm_prob': 4.85466926132349e-05}
# #  87/100 - Metric: 0.342 - Parameter: {'look_back_len': 39, 'sigma_v': 0.120162924914516, 'std_transition_error': 9.057778684913691e-05, 'norm_to_abnorm_prob': 4.371508410413899e-05}
# #  88/100 - Metric: 0.334 - Parameter: {'look_back_len': 39, 'sigma_v': 0.12002079346304187, 'std_transition_error': 9.64485328416763e-05, 'norm_to_abnorm_prob': 6.828180621109775e-05}
# #  89/100 - Metric: 0.423 - Parameter: {'look_back_len': 42, 'sigma_v': 0.14696225684937758, 'std_transition_error': 9.850372825808649e-05, 'norm_to_abnorm_prob': 5.6457505225006327e-05}
# #  90/100 - Metric: 0.318 - Parameter: {'look_back_len': 38, 'sigma_v': 0.14211113977097414, 'std_transition_error': 9.582795349370401e-05, 'norm_to_abnorm_prob': 6.515070375897052e-05}
# #  91/100 - Metric: 1.296 - Parameter: {'look_back_len': 40, 'sigma_v': 0.10687287630068315, 'std_transition_error': 8.821665899209613e-05, 'norm_to_abnorm_prob': 8.887808101733504e-05}
# #  92/100 - Metric: 0.359 - Parameter: {'look_back_len': 36, 'sigma_v': 0.14798438509558054, 'std_transition_error': 8.8037359718675e-05, 'norm_to_abnorm_prob': 6.851279945486488e-05}
# #  93/100 - Metric: 1.336 - Parameter: {'look_back_len': 40, 'sigma_v': 0.08883173586746945, 'std_transition_error': 9.163289676529209e-05, 'norm_to_abnorm_prob': 6.843028871452114e-05}
# #  94/100 - Metric: 0.807 - Parameter: {'look_back_len': 35, 'sigma_v': 0.09481847862382171, 'std_transition_error': 9.639639970580212e-05, 'norm_to_abnorm_prob': 7.588906242070788e-05}
# #  95/100 - Metric: 0.415 - Parameter: {'look_back_len': 44, 'sigma_v': 0.16063088079557575, 'std_transition_error': 9.845737189063695e-05, 'norm_to_abnorm_prob': 7.586045035258763e-05}
# #  96/100 - Metric: 2.436 - Parameter: {'look_back_len': 34, 'sigma_v': 0.004525436792503529, 'std_transition_error': 2.3000123901401475e-05, 'norm_to_abnorm_prob': 8.015603889170765e-05}
# #  97/100 - Metric: 0.464 - Parameter: {'look_back_len': 42, 'sigma_v': 0.16179832246246734, 'std_transition_error': 7.305477233084805e-05, 'norm_to_abnorm_prob': 5.14374585650479e-05}
# #  98/100 - Metric: 0.325 - Parameter: {'look_back_len': 38, 'sigma_v': 0.1592096671104024, 'std_transition_error': 9.8156789562661e-05, 'norm_to_abnorm_prob': 5.984500287713948e-05}
# #  99/100 - Metric: 0.294 - Parameter: {'look_back_len': 31, 'sigma_v': 0.1398832407089792, 'std_transition_error': 9.540963152458303e-05, 'norm_to_abnorm_prob': 6.685649794173676e-05}
# 2025-11-19 10:16:59,645	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/Users/vuongdai/ray_results/Model_optimizer' in 0.0278s.
# # 100/100 - Metric: 0.362 - Parameter: {'look_back_len': 37, 'sigma_v': 0.1866118653634212, 'std_transition_error': 9.989311716127419e-05, 'norm_to_abnorm_prob': 7.913477335659384e-05}
# -----
# Optimal parameters at trial #99: {'look_back_len': 31, 'sigma_v': 0.1398832407089792, 'std_transition_error': 9.540963152458303e-05, 'norm_to_abnorm_prob': 6.685649794173676e-05}
# -----
